# %% [markdown]
# **Esplorazione Dataset comuni Toscana**
#
# Importiamo pandas e salviamo il dataset in un DataFrame.

# %%
import pandas as pd

# %%
df = pd.read_csv("../../datasets/salute/osservatori_comuni.csv")
df.head(5)
# Out:
#                 tipo  id_pis_settore             pis_settore  id_ind_pis  \
# 0  Set complementare               2  Determinanti di salute         254
# 1         Set minimo               1     Profilo demografico          24
# 2  Set complementare               2  Determinanti di salute         311
# 3  Set complementare               2  Determinanti di salute         311
# 4  Set complementare               2  Determinanti di salute         254
#
#            codice_pis                                    nome_indicatore  \
# 0  SC.determinanti.7a  Percentuale studenti con esito negativo - prim...
# 1           SM.demo.6                   Percentuale stranieri residenti
# 2  SC.determinanti.35        Numero interventi di controllo per abitante
# 3  SC.determinanti.35        Numero interventi di controllo per abitante
# 4  SC.determinanti.7a  Percentuale studenti con esito negativo - prim...
#
#    id_comuni             comuni               asl prov  2007      2008  2009  \
# 0    9051036               Stia   AUSL 8 - Arezzo   AR   NaN  0.000000     0
# 1    9051041  Pratovecchio Stia   AUSL 8 - Arezzo   AR   NaN       NaN   NaN
# 2    9051006           Capolona   AUSL 8 - Arezzo   AR   NaN       NaN     1
# 3    9051004           Bibbiena   AUSL 8 - Arezzo   AR   NaN       NaN     1
# 4    9047004         Cutigliano  AUSL 3 - Pistoia   PT   NaN  3.773585     0
#
#    2010  2011  2012  2013       2014
# 0     0     0     0     0        NaN
# 1   NaN   NaN   NaN   NaN  12.137158
# 2   NaN   NaN   NaN   NaN        NaN
# 3     2   NaN   NaN   NaN        NaN
# 4     0     0     0     0        NaN

# %% [markdown]
# Il DataFrame è organizzato in maniera da salvare i dati rilevanti in diverse colonne a seconda dell'anno di rilevazione. Per sapere a quale dato si riferisce una cella bisogna fare riferimento al valore nella colonna _nome indicatore_.
#
# Trasformiamo la struttura del DataFrame in una più facile da analizzare utilizzando _pandas_.
#
# La struttura sarà la seguente
#
# | Comune        | Anno          | Indicatore 1  | Indicatore 2  | ... |
# | ------------- |:-------------:| -------------:| -------------:| ---:|
# | Firenze       | 2007          | 1600          | 45            | ... |
# | Vaiano        | 2008          |   12          | 55            | ... |
# | Vernio        | 2009          |    1          | 66            | ... |

# %% [markdown]
# Andiamo a guardare gli indicatori presenti nel DataFrame e selezioniamo quelli di interesse

# %%
df.nome_indicatore.unique()
# Out:
# array(['Percentuale studenti con esito negativo - primaria',
#        'Percentuale stranieri residenti ',
#        'Numero interventi di controllo per abitante',
#        'Indice di dinamicit\xc3\xa0 degli avviamenti',
#        'Indice di dinamicit\xc3\xa0 degli avviamenti di stranieri',
#        'Indice di presenza delle coop sociali formalizzate (x 10.000)',
#        'Tasso di pensioni di invalidit\xc3\xa0 civile 0-19 anni (x 100)',
#        'Tasso di famiglie che chiedono integrazione canoni di locazione (x 1000)',
#        'Tasso di natalit\xc3\xa0 (x 1.000)',
#        'Percentuale studenti con esito negativo - secondaria I grado',
#        'Tasso di ricettivit\xc3\xa0 dei servizi educativi per la prima infanzia (x 100)',
#        'Tasso di accoglienza dei servizi educativi per la prima infanzia (x 100)',
#        "Importo medio mensile pensioni invalidit\xc3\xa0 erogate dall'INPS",
#        "Importo medio mensile pensioni pensioni/assegni sociali erogate dall'INPS",
#        'Tasso grezzo di disoccupazione (x100)',
#        'Tasso grezzo di disoccupazione stranieri (x100)',
#        'Indice di presenza della promozione sociale formalizzata (x 10.000)',
#        'Produzione pro-capite Rifiuti Urbani',
#        'Percentuale studenti stranieri iscritti alle scuole secondarie di primo grado',
#        'Percentuale studenti stranieri iscritti alle scuole secondarie di secondo grado',
#        'Incidenza dei flussi annuali di avviamenti al lavoro nel collocamento mirato (x 100)',
#        'Incidenza dei flussi annuali di cessazioni dal lavoro nel collocamento mirato (x 100)',
#        'Indice di vecchiaia (x 100)',
#        'Indice di dipendenza anziani (x 100)',
#        'Quoziente di incremento totale (x 1.000)',
#        "Importo medio mensile pensioni totali erogate dall'INPS",
#        'Quoziente di incremento naturale (x 1.000)',
#        'Quoziente di incremento migratorio (x 1.000)',
#        'Reddito imponibile medio per contribuente',
#        'Tasso di pensioni sociali e assegni sociali (x 100)',
#        "Importo medio mensile pensioni invalidi civili erogate dall'INPS",
#        "Importo medio mensile pensioni vecchiaia erogate dall'INPS",
#        "Importo medio mensile pensioni superstite erogate dall'INPS",
#        'Incidenza dei disabili disponibili al lavoro (x100)',
#        'Percentuale nati di cittadinanza non italiana',
#        'Indice di instabilit\xc3\xa0 matrimoniale (x100)',
#        'Numero medio componenti per famiglie',
#        '% di Raccolta Differenziata',
#        'Reddito imponibile medio per residente',
#        'Indice di supporto ai grandi anziani (x 100)',
#        'Percentuale studenti con esito negativo - secondaria II grado',
#        'Incidenza dei flussi annuali di avviamenti al lavoro (x 100)',
#        'Rapporto tra avviamenti/cessazioni (x 100)',
#        'Incidenza dei flussi annuali di avviamenti al lavoro di stranieri (x 100)',
#        'Rapporto tra avviamenti/cessazioni di stranieri (x 100)',
#        'Percentuale di avviamenti a termine',
#        'Indice di presenza del Terzo settore formalizzato (x 10.000)',
#        'Indice di presenza del volontariato formalizzato (x 10.000)',
#        'Superamento dei limiti normativi dovuti a Srb: numero superamenti limite di esposizione e limite di attenzione',
#        'Tasso di pensioni di invalidit\xc3\xa0 civile 20-64 anni (x 100)',
#        'Superamento dei limiti normativi dovuti a impianti Rtv: numero superamenti limite di esposizione e limite di attenzione',
#        'Tasso di pensioni di invalidit\xc3\xa0 civile 65-79 anni (x 100)',
#        'Tasso di pensioni di invalidit\xc3\xa0 civile 80+ anni (x 100)',
#        'Tasso di pensioni di invalidit\xc3\xa0 civile (x 100)',
#        'Indice di dipendenza giovanile ridefinito'], dtype=object)

# %%
interesting_feat = ["Produzione pro-capite Rifiuti Urbani","Reddito imponibile medio per contribuente",
                    "Numero medio componenti per famiglie","% di Raccolta Differenziata",
                    "Reddito imponibile medio per residente","Rapporto tra avviamenti/cessazioni (x 100)",
                    "Rapporto tra avviamenti/cessazioni di stranieri (x 100)",'Tasso grezzo di disoccupazione (x100)',
                    "Tasso grezzo di disoccupazione stranieri (x100)","Quoziente di incremento totale (x 1.000)",
                    "Percentuale nati di cittadinanza non italiana","Tasso di pensioni sociali e assegni sociali (x 100)",
                    "Percentuale studenti con esito negativo - secondaria II grado",
                    "Superamento dei limiti normativi dovuti a Srb: numero superamenti limite di esposizione e limite di attenzione",
                    "Superamento dei limiti normativi dovuti a impianti Rtv: numero superamenti limite di esposizione e limite di attenzione",
                    "Percentuale di avviamenti a termine","Percentuale studenti con esito negativo - secondaria I grado",
                   "Numero interventi di controllo per abitante"]
#interesting_feat = list(df.nome_indicatore.unique())

# %% [markdown]
# Possiamo ora ridurre le dimensioni del DataFrame e salvare soltanto le righe con gli indicatori di interesse.
# Chiamiamo il nuovo DataFrame *df_skim*.

# %%
df_skim = df[df.nome_indicatore.isin(interesting_feat)]

# %%
df_skim.head(5)
# Out:
#                  tipo  id_pis_settore             pis_settore  id_ind_pis  \
# 2   Set complementare               2  Determinanti di salute         311
# 3   Set complementare               2  Determinanti di salute         311
# 6   Set complementare               2  Determinanti di salute         311
# 9   Set complementare               2  Determinanti di salute         311
# 10  Set complementare               2  Determinanti di salute         311
#
#             codice_pis                              nome_indicatore  \
# 2   SC.determinanti.35  Numero interventi di controllo per abitante
# 3   SC.determinanti.35  Numero interventi di controllo per abitante
# 6   SC.determinanti.35  Numero interventi di controllo per abitante
# 9   SC.determinanti.35  Numero interventi di controllo per abitante
# 10  SC.determinanti.35  Numero interventi di controllo per abitante
#
#     id_comuni               comuni                asl prov  2007  2008  2009  \
# 2     9051006             Capolona    AUSL 8 - Arezzo   AR   NaN   NaN     1
# 3     9051004             Bibbiena    AUSL 8 - Arezzo   AR   NaN   NaN     1
# 6     9048041            Scandicci  AUSL 10 - Firenze   FI   NaN     1     1
# 9     9050035  Santa Maria a Monte      AUSL 5 - Pisa   PI   NaN     1     1
# 10    9050040  Casciana Terme Lari      AUSL 5 - Pisa   PI   NaN     1     1
#
#     2010  2011  2012  2013  2014
# 2    NaN   NaN   NaN   NaN   NaN
# 3      2   NaN   NaN   NaN   NaN
# 6    NaN   NaN   NaN   NaN   NaN
# 9    NaN   NaN   NaN   NaN   NaN
# 10   NaN   NaN   NaN   NaN   NaN

# %% [markdown]
# Salviamo ora la lista dei comuni che ci serve per raggruppare gli indicatori per comune e anno di rilevazione in un nuovo DataFrame.

# %%
list_comuni = df_skim.comuni.unique()
print list_comuni
# Out:
# ['Capolona' 'Bibbiena' 'Scandicci' 'Santa Maria a Monte'
#  'Casciana Terme Lari' 'Castagneto Carducci' 'Cecina' 'Montevarchi'
#  'Terranuova Bracciolini' 'Peccioli' 'Vaiano' 'Ponsacco' 'Pontedera'
#  'Santa Luce' 'Capannori' 'Lucca' 'Porcari' 'Villa Basilica'
#  'Bagni di Lucca' 'Barga' 'Borgo a Mozzano' 'Cantagallo' 'Carmignano'
#  'Poggio a Caiano' "Campo nell'Elba" 'Portoferraio' 'Livorno' 'Piombino'
#  'San Vincenzo' 'Loro Ciuffenna' "Colle Val d'Elsa" 'Subbiano'
#  'Pratovecchio' 'Castiglion Fiorentino' 'Pratovecchio Stia' 'Monterchi'
#  'Monte Argentario' 'Orbetello' 'Fosciandora' 'Chitignano' 'Grosseto'
#  'Castelnuovo di Garfagnana' 'Campi Bisenzio' 'Greve in Chianti'
#  'Coreglia Antelminelli' 'Pieve Fosciana' 'Impruneta' 'Pelago'
#  'Fabbriche di Vergemoli' 'Agliana' 'Montale' 'Pistoia' 'Quarrata'
#  'Sambuca Pistoiese' 'Serravalle Pistoiese' 'Buggiano' 'Lamporecchio'
#  'Larciano' 'Massa e Cozzile' 'Pontassieve' 'Monsummano Terme'
#  'Montecatini Terme' 'Pescia' 'Pieve a Nievole' 'Ponte Buggianese' 'Uzzano'
#  'Signa' 'Chiesina Uzzanese' 'Pomarance' 'Calci' 'Cascina' 'Fauglia' 'Pisa'
#  'San Giuliano Terme' 'Vecchiano' 'Vicopisano' 'Bientina'
#  'Rosignano Marittimo' 'Casale Marittimo' 'Castelnuovo Berardenga'
#  'Poggibonsi' 'San Gimignano' 'San Casciano Val di Pesa' 'Asciano'
#  'Castellina in Chianti' 'Tavarnelle Val di Pesa' 'Firenze' 'Chiusdino'
#  'Monteriggioni' "Monteroni d'Arbia" 'Rapolano Terme' 'Siena' 'Carrara'
#  'Massa' 'Montignoso' 'Aulla' 'Bagnone' 'Casola in Lunigiana' 'Comano'
#  'Filattiera' 'Fivizzano' 'Fosdinovo' 'Licciana Nardi' 'Mulazzo'
#  'Podenzana' 'Pontremoli' 'Tresana' 'Villafranca in Lunigiana' 'Zeri'
#  'Altopascio' 'Montecarlo' 'Pescaglia' 'Camporgiano' 'Careggine'
#  'Castiglione di Garfagnana' 'Gallicano' 'Giuncugnano' 'Minucciano'
#  'Molazzana' 'Piazza al Serchio' 'San Romano in Garfagnana' 'Sillano'
#  'Vagli Sotto' 'Villa Collemandina' 'Abetone' 'Cutigliano' 'Marliana'
#  'Piteglio' 'San Marcello Pistoiese' 'Castelnuovo Val di Cecina'
#  'Montecatini Val di Cecina' 'Volterra' 'Orciano Pisano'
#  'Crespina Lorenzana' 'Buti' 'Calcinaia' 'Capannoli' 'Chianni' 'Lajatico'
#  'Palaia' 'Terricciola' 'Bibbona' 'Castellina Marittima' 'Guardistallo'
#  'Montescudaio' 'Riparbella' 'Capoliveri' 'Marciana' 'Marciana Marina'
#  'Porto Azzurro' 'Rio Marina' "Rio nell'Elba" 'Capraia Isola'
#  'Collesalvetti' 'Campiglia Marittima' 'Sassetta' 'Suvereto'
#  'Monteverdi Marittimo' "Casole d'Elsa" 'Radicondoli'
#  'Abbadia San Salvatore' "Castiglione d'Orcia" 'Piancastagnaio'
#  'Radicofani' "San Quirico d'Orcia" 'Buonconvento' 'Gaiole in Chianti'
#  'Montalcino' 'Monticiano' 'Murlo' 'Radda in Chianti' "San Giovanni d'Asso"
#  'Sovicille' 'Cetona' 'Chianciano Terme' 'Chiusi' 'Montepulciano' 'Pienza'
#  'San Casciano dei Bagni' 'Sarteano' 'Sinalunga' 'Torrita di Siena'
#  'Trequanda' 'Arezzo' 'Castiglion Fibocchi' 'Civitella in Val di Chiana'
#  'Monte San Savino' 'Castel Focognano' 'Castel San Niccol\xc3\xb2'
#  'Chiusi della Verna' 'Montemignaio' 'Ortignano Raggiolo' 'Poppi' 'Stia'
#  'Talla' 'Cortona' 'Foiano della Chiana' 'Lucignano'
#  'Marciano della Chiana' 'Anghiari' 'Badia Tedalda' 'Caprese Michelangelo'
#  'Pieve Santo Stefano' 'Sansepolcro' 'Sestino' 'Bucine' 'Cavriglia'
#  'Laterina' 'Pergine Valdarno' 'San Giovanni Valdarno'
#  'Castelfranco Piandisc\xc3\xb2' 'Arcidosso' 'Castel del Piano'
#  "Castell'Azzara" 'Cinigiano' 'Roccalbegna' 'Santa Fiora' 'Seggiano'
#  'Semproniano' 'Capalbio' 'Isola del Giglio' 'Magliano in Toscana'
#  'Manciano' 'Pitigliano' 'Sorano' 'Follonica' 'Gavorrano' 'Massa Marittima'
#  'Montieri' 'Scarlino' 'Monterotondo Marittimo' 'Campagnatico'
#  'Castiglione della Pescaia' 'Civitella Paganico' 'Roccastrada' 'Scansano'
#  'Calenzano' 'Fiesole' 'Lastra a Signa' 'Sesto Fiorentino' 'Vaglia'
#  'Bagno a Ripoli' "Barberino Val d'Elsa" 'Londa' 'Reggello'
#  "Rignano sull'Arno" 'Rufina' 'San Godenzo' 'Figline e Incisa Valdarno'
#  'Barberino di Mugello' 'Borgo San Lorenzo' 'Dicomano' 'Firenzuola'
#  'Marradi' 'Palazzuolo sul Senio' 'Vicchio' 'Scarperia e San Piero'
#  'Capraia e Limite' 'Castelfiorentino' 'Cerreto Guidi' 'Certaldo' 'Empoli'
#  'Fucecchio' 'Gambassi Terme' 'Montaione' 'Montelupo Fiorentino'
#  'Montespertoli' 'Vinci' 'Castelfranco di Sotto' "Montopoli in Val d'Arno"
#  'San Miniato' "Santa Croce sull'Arno" 'Camaiore' 'Forte dei Marmi'
#  'Massarosa' 'Pietrasanta' 'Seravezza' 'Stazzema' 'Viareggio' 'Prato'
#  'Montemurlo' 'Vernio']

# %% [markdown]
# Salviamo ora i dati relativi ai comuni in una lista di n-tuple.
# Le n-tuple avranno come prime 2 entry il nome del comune e l'anno. Le restanti entry sono le _interesting feat_ che abbiamo definito sopra.

# %%
test_list = []
for com in list_comuni:
    for year in range(2007,2015):
        test_tuple = (com,year)
        for name in interesting_feat:
            #print name
            df_temp = df_skim[(df_skim["nome_indicatore"] == name) & (df_skim["comuni"]==com)]
            #print df_temp["2007"]
            #print df_temp.shape
            if df_temp.empty == True: 
                continue
            test_tuple = test_tuple + (df_temp.iloc[0][str(year)],)
    
        test_list.append(test_tuple)

# %% [markdown]
# Creiamo un nuovo DataFrame _df new_ a partire dalla lista di n-tuple creata sopra.

# %%
df_new = pd.DataFrame(test_list,columns=["comune","year"]+interesting_feat)

# %% [markdown]
# Controlliamo adesso che tutto sia andato bene.
# Possiamo fare un cross-check per uno dei comuni. Prendiamo i dati dal DataFrame originale e li confrontiamo con il DataFrame appena creato.
# Usiamo il comune di "Pratovecchio Stia" per il confronto.

# %%
df_skim[df_skim.comuni=="Pratovecchio Stia"]
# Out:
#                     tipo  id_pis_settore  \
# 62            Set minimo               2
# 65            Set minimo               2
# 75            Set minimo               2
# 1426          Set minimo               1
# 2058          Set minimo               2
# 2551          Set minimo               2
# 5862          Set minimo               2
# 6420          Set minimo               2
# 6703          Set minimo               2
# 7258          Set minimo               7
# 9718   Set complementare               2
# 11068  Set complementare               2
# 11609  Set complementare               2
#
#                                   pis_settore  id_ind_pis          codice_pis  \
# 62                     Determinanti di salute          61   SM.determinanti.6
# 65                     Determinanti di salute          65   SM.determinanti.8
# 75                     Determinanti di salute          79  SM.determinanti.19
# 1426                      Profilo demografico          26           SM.demo.7
# 2058                   Determinanti di salute          35   SM.determinanti.2
# 2551                   Determinanti di salute          38   SM.determinanti.3
# 5862                   Determinanti di salute          69  SM.determinanti.10
# 6420                   Determinanti di salute          81  SM.determinanti.20
# 6703                   Determinanti di salute         483  SM.determinanti.2b
# 7258   Ass. sociosanitaria: famiglie e minori         167       SM.famiglie.1
# 9718                   Determinanti di salute         265   SC.determinanti.9
# 11068                  Determinanti di salute         276  SC.determinanti.14
# 11609                  Determinanti di salute         282  SC.determinanti.16
#
#                                          nome_indicatore  id_comuni  \
# 62                 Tasso grezzo di disoccupazione (x100)    9051041
# 65       Tasso grezzo di disoccupazione stranieri (x100)    9051041
# 75                  Produzione pro-capite Rifiuti Urbani    9051041
# 1426            Quoziente di incremento totale (x 1.000)    9051041
# 2058           Reddito imponibile medio per contribuente    9051041
# 2551   Tasso di pensioni sociali e assegni sociali (x...    9051041
# 5862                Numero medio componenti per famiglie    9051041
# 6420                         % di Raccolta Differenziata    9051041
# 6703              Reddito imponibile medio per residente    9051041
# 7258       Percentuale nati di cittadinanza non italiana    9051041
# 9718          Rapporto tra avviamenti/cessazioni (x 100)    9051041
# 11068  Rapporto tra avviamenti/cessazioni di stranier...    9051041
# 11609                Percentuale di avviamenti a termine    9051041
#
#                   comuni              asl prov  2007  2008  2009  2010  2011  \
# 62     Pratovecchio Stia  AUSL 8 - Arezzo   AR   NaN   NaN   NaN   NaN   NaN
# 65     Pratovecchio Stia  AUSL 8 - Arezzo   AR   NaN   NaN   NaN   NaN   NaN
# 75     Pratovecchio Stia  AUSL 8 - Arezzo   AR   NaN   NaN   NaN   NaN   NaN
# 1426   Pratovecchio Stia  AUSL 8 - Arezzo   AR   NaN   NaN   NaN   NaN   NaN
# 2058   Pratovecchio Stia  AUSL 8 - Arezzo   AR   NaN   NaN   NaN   NaN   NaN
# 2551   Pratovecchio Stia  AUSL 8 - Arezzo   AR   NaN   NaN   NaN   NaN   NaN
# 5862   Pratovecchio Stia  AUSL 8 - Arezzo   AR   NaN   NaN   NaN   NaN   NaN
# 6420   Pratovecchio Stia  AUSL 8 - Arezzo   AR   NaN   NaN   NaN   NaN   NaN
# 6703   Pratovecchio Stia  AUSL 8 - Arezzo   AR   NaN   NaN   NaN   NaN   NaN
# 7258   Pratovecchio Stia  AUSL 8 - Arezzo   AR   NaN   NaN   NaN   NaN   NaN
# 9718   Pratovecchio Stia  AUSL 8 - Arezzo   AR   NaN   NaN   NaN   NaN   NaN
# 11068  Pratovecchio Stia  AUSL 8 - Arezzo   AR   NaN   NaN   NaN   NaN   NaN
# 11609  Pratovecchio Stia  AUSL 8 - Arezzo   AR   NaN   NaN   NaN   NaN   NaN
#
#                2012          2013          2014
# 62              NaN           NaN     25.644542
# 65              NaN           NaN     49.562172
# 75              NaN           NaN    524.580377
# 1426            NaN           NaN     -9.675777
# 2058   20662.413962  20892.793628  21158.915460
# 2551            NaN           NaN      2.306733
# 5862            NaN           NaN      2.172530
# 6420            NaN           NaN     22.694312
# 6703            NaN           NaN  12150.842132
# 7258            NaN           NaN     22.222222
# 9718            NaN           NaN     72.849250
# 11068           NaN           NaN    100.854701
# 11609           NaN           NaN     82.448537

# %%
df_new[df_new.comune=="Pratovecchio Stia"]
# Out:
#                 comune  year  Produzione pro-capite Rifiuti Urbani  \
# 272  Pratovecchio Stia  2007                                   NaN
# 273  Pratovecchio Stia  2008                                   NaN
# 274  Pratovecchio Stia  2009                                   NaN
# 275  Pratovecchio Stia  2010                                   NaN
# 276  Pratovecchio Stia  2011                                   NaN
# 277  Pratovecchio Stia  2012                                   NaN
# 278  Pratovecchio Stia  2013                                   NaN
# 279  Pratovecchio Stia  2014                            524.580377
#
#      Reddito imponibile medio per contribuente  \
# 272                                        NaN
# 273                                        NaN
# 274                                        NaN
# 275                                        NaN
# 276                                        NaN
# 277                               20662.413962
# 278                               20892.793628
# 279                               21158.915460
#
#      Numero medio componenti per famiglie  % di Raccolta Differenziata  \
# 272                                   NaN                          NaN
# 273                                   NaN                          NaN
# 274                                   NaN                          NaN
# 275                                   NaN                          NaN
# 276                                   NaN                          NaN
# 277                                   NaN                          NaN
# 278                                   NaN                          NaN
# 279                               2.17253                    22.694312
#
#      Reddito imponibile medio per residente  \
# 272                                     NaN
# 273                                     NaN
# 274                                     NaN
# 275                                     NaN
# 276                                     NaN
# 277                                     NaN
# 278                                     NaN
# 279                            12150.842132
#
#      Rapporto tra avviamenti/cessazioni (x 100)  \
# 272                                         NaN
# 273                                         NaN
# 274                                         NaN
# 275                                         NaN
# 276                                         NaN
# 277                                         NaN
# 278                                         NaN
# 279                                    72.84925
#
#      Rapporto tra avviamenti/cessazioni di stranieri (x 100)  \
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                         100.854701
#
#      Tasso grezzo di disoccupazione (x100)  \
# 272                                    NaN
# 273                                    NaN
# 274                                    NaN
# 275                                    NaN
# 276                                    NaN
# 277                                    NaN
# 278                                    NaN
# 279                              25.644542
#
#      Tasso grezzo di disoccupazione stranieri (x100)  \
# 272                                              NaN
# 273                                              NaN
# 274                                              NaN
# 275                                              NaN
# 276                                              NaN
# 277                                              NaN
# 278                                              NaN
# 279                                        49.562172
#
#      Quoziente di incremento totale (x 1.000)  \
# 272                                       NaN
# 273                                       NaN
# 274                                       NaN
# 275                                       NaN
# 276                                       NaN
# 277                                       NaN
# 278                                       NaN
# 279                                 -9.675777
#
#      Percentuale nati di cittadinanza non italiana  \
# 272                                            NaN
# 273                                            NaN
# 274                                            NaN
# 275                                            NaN
# 276                                            NaN
# 277                                            NaN
# 278                                            NaN
# 279                                      22.222222
#
#      Tasso di pensioni sociali e assegni sociali (x 100)  \
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                           2.306733
#
#      Percentuale studenti con esito negativo - secondaria II grado  \
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                          82.448537
#
#      Superamento dei limiti normativi dovuti a Srb: numero superamenti limite di esposizione e limite di attenzione  \
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                                NaN
#
#      Superamento dei limiti normativi dovuti a impianti Rtv: numero superamenti limite di esposizione e limite di attenzione  \
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                                NaN
#
#      Percentuale di avviamenti a termine  \
# 272                                  NaN
# 273                                  NaN
# 274                                  NaN
# 275                                  NaN
# 276                                  NaN
# 277                                  NaN
# 278                                  NaN
# 279                                  NaN
#
#      Percentuale studenti con esito negativo - secondaria I grado  \
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                                NaN
#
#      Numero interventi di controllo per abitante
# 272                                          NaN
# 273                                          NaN
# 274                                          NaN
# 275                                          NaN
# 276                                          NaN
# 277                                          NaN
# 278                                          NaN
# 279                                          NaN

# %% [markdown]
# Campionando alcune celle dal primo DataFrame e conforntandole con il secondo sembra che i valori corrispondano.
# Check passato.
#
# Salviamo ora il nuovo DataFrame in un file _csv_ per la futura analisi.

# %%
df_new.to_csv("../../datasets/salute/osservatori_comuni_cleaned.csv")
